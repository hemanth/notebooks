# %%
pip install -qr https://huggingface.co/briaai/RMBG-1.4/resolve/main/requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# ![](https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQQziABManqQJD6GMH2xJiP2wf-1uAMnt3r6YrgwkR1lcInB30YzVK1rSCyNdtMTGmXhKaGejyiILxTUuREzraEUw)

# %% [markdown]
# [](https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQQziABManqQJD6GMH2xJiP2wf-1uAMnt3r6YrgwkR1lcInB30YzVK1rSCyNdtMTGmXhKaGejyiILxTUuREzraEUw)

# %%
from transformers import pipeline
image_path = "https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQQziABManqQJD6GMH2xJiP2wf-1uAMnt3r6YrgwkR1lcInB30YzVK1rSCyNdtMTGmXhKaGejyiILxTUuREzraEUw"
pipe = pipeline("image-segmentation", model="briaai/RMBG-1.4", trust_remote_code=True)
pillow_mask = pipe(image_path, return_mask = True)
pillow_image = pipe(image_path)
pillow_image
# Out:
# <PIL.Image.Image image mode=RGBA size=554x554>
